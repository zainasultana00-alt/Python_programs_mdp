# %% [markdown]
# # conditional statments in python

# %%
# conditional statements in python
1. python have 3 types of conditional statements
2. if condition
3. elif condition
4. else condition
```python
if (logic):
    statements
    ```

```python if,else
s
else:
    statements
```

```python if,elif,else
if(logic)
    statement
elif(logic):
     statements
else(logic):
     statements
```

# %%
# write a program to check given number is even number or odd number
num=int(input("please enter first number here:"))
if(num%2==0):
    print(num,"is even number")
else:
    print(num,"is odd number")
# Out:
# please enter first number here: 25
# 25 is odd number

# %%
#write a program to find the number is positive or negative or zero
n=int(input("enter number here:"))
if(n>0):
    print("positive number")
elif(n<0):
    print("negative number")
else:
    print("zero")
# Out:
# enter number here: -5
# negative number

# %%
"""
student grading systems
1. if marks in between 80 to 100 then A grade
2. if marks in between 60 to 80 then B grade
3. if marks in between 40 to 60 then C grade
4. if marks in betwen 25 to 40 then D grade
5. if marks in between 0 to 25 then Fail
6. other than above marks output shuold  be please enter valid marks 
"""

marks=int(input("please enter marks here:"))
if (marks>=80 and marks<=100):
    print("A grade")
elif(marks>=60 and marks<80):
    print("B grade")
elif(marks>=40 and marks<60):
    print("C grade")
elif(marks>=25 and marks<40)
     print("D grade")
elif(marks>=0 and marks<25):
   print("Fail")
else:
     print("please enter valid marks")
# Out:
#   Cell In[5], line 18
#     elif(marks>=25 and marks<40)
#                                 ^
# SyntaxError: expected ':'

# %% [raw]
# # write a program to find the largest number from three numbers
# # write a program to check login credentials using conditional statements
# # write a calculator program using conditonal statements
